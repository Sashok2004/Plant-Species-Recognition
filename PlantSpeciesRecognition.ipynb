# %%
# Проект: Распознавание видов растений

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Проект создан")
print("Тема: Распознавание видов растений")
# Out:
# Проект создан
# Тема: Распознавание видов растений
